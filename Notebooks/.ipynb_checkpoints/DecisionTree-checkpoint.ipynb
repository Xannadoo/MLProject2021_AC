# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter

from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Paths

# %%
TRAIN = '../Data/df_train.csv'
TEST = '../Data/df_test.csv'

# %% [markdown]
# ## Functions

# %%
z_score = lambda x : (x-np.mean(x,axis=0))/ np.std(x,axis=0) #code from exercise 5

# %% [markdown]
# ## Variables and df loading

# %%
col = 'tab10' #colour theme

df = pd.read_csv(TRAIN) #training dataframe

attributes = list(df.columns)[:-1] #creates list of column names for later, without the class

X = df[attributes].round(3).copy() #attributes
df[attributes] = df[attributes].round(3)
y = df['type'].copy() #true values
df['type_desc'] = ''
y_types = {1:'wind_float', 2:'wind_non', 3:'wind_veh', 5:'container', 6:'tableware', 7:'headlamp'}
y_list = y.unique() #'y' values

X_std = z_score(X) #standardizes X as later we see they are on different scales

for i in y_list: #this changes the 'type' to a descriptive word rather than a number
    #This is more human readable for plotting later - 'y' is still using the numbers
    df['type_desc'][df['type'] == i] = y_types[i]
    
df.head(3)
# Out:
#       RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  type type_desc
# 0  1.518  12.85  3.67  1.24  72.57  0.62  8.68  0.0  0.35     2  wind_non
# 1  1.521  13.78  2.28  1.43  71.99  0.49  9.85  0.0  0.17     2  wind_non
# 2  1.517  13.72  3.68  1.81  72.06  0.64  7.88  0.0  0.00     2  wind_non

# %%
def Gini(g_df, y,threshold):
    '''Takes a threshold and calc the Gini impurity of each split of the given df'''
    g_df = pd.concat([g_df,y], axis=1,)
    g_df.columns=['Att', 'class']
    #print(df.head())
    
    class_count = np.zeros((8), dtype=int)
    for i in range(len(g_df)):
        class_count[g_df['class'].iloc[i]]+=1        
    class_count = np.delete(class_count, [0,4])
    #print(class_count)

    proportion = [class_count[i]/np.sum(class_count) for i in range(len(class_count))]
    #print([round(i,3) for i in proportion])
    node_gini = 0
    for i in range(len(proportion)):
        node_gini += proportion[i]*(1-proportion[i])  
    
    df_a = g_df[g_df['Att'] <= threshold]
    df_b = g_df[g_df['Att'] > threshold]
    
    n = g_df.shape[0]
    n_a = df_a.shape[0]
    n_b = df_b.shape[0]
    
    
    #calc and return gini impurity for each side
    #print(len(df_a))
    #print(len(df_b))
    gini_a = 0
    gini_b = 0
    
    for i in y_list: #loop through all classes
        
        k_a = df_a[df_a['class'] == i] 
        p_ka = len(k_a)/len(df_a) #count number of class k in first split, divided by total in that split.
        
        k_b = df_b[df_b['class'] == i]
        p_kb = len(k_b)/len(df_b) #count number of class k in first split, divided by total in that split.
        
        #print(i, k_a,k_b)
        
        gini_a += (p_ka* (1-p_ka)) #p*(1-p)
        gini_b += (p_kb* (1-p_kb)) #p*(1-p)
        

    #print(round(gini_a, 3), round(gini_b, 3)) #The leaves gini scores are correct!
    
    return round((n_a/n)*gini_a + (n_b/n)*gini_b, 3), round(node_gini,3), class_count #weighted gini from leaves != overall node gini

        
        
Gini(df['Ba'],y, 0.4) #0.736
# Out:
# (0.62, 0.736, array([49, 53, 12,  9,  6, 20]))

# %%
def leaf_hunter(df):
    '''takes df and class returns best weighted leaf gini scores, best threshold, 
    best attribute and node gini score'''
    #So many dratted loops! 
    best_gini = 1
    best_class = ''
    best_threshold = 0
    best_att = 0
    class_cnt = 0
    node_gini = 0
    if df.shape[0] == 1:
        class_count = np.zeros((8), dtype=int)
        for i in range(len(df)):
            class_count[df['type'].iloc[i]]+=1        
            class_count = np.delete(class_count, [0,4])
        return {'best_gini': 0, 
                'best_threshold': 0, 
                'best_att': 0, 
                'node_gini': 0,
                'class_count': class_count}
    for a in attributes: #loop through attributes
        tmp = df.sort_values(by=a, axis=0).copy()
        
        for threshold in range(len(df)-1): #loop through potential thresholds
            
            if tmp[a].iloc[threshold] != tmp[a].iloc[threshold+1]: #skip if the two points are the same value
                thresh = round((tmp[a].iloc[threshold] + tmp[a].iloc[threshold+1])/2,4)
                #print((tmp[a].iloc[threshold], tmp[a].iloc[threshold+1]), thresh)       
                gini, node_gini, class_count = Gini(df[a], df['type'], thresh)
                
                if gini < best_gini:
                    best_gini = gini
                    best_threshold = thresh
                    best_att = a
                    class_cnt = class_count
                
    return {'best_gini': best_gini, 
            'best_threshold': best_threshold, 
            'best_att': best_att, 
            'node_gini': node_gini,
            'class_count': class_count}


            
leaf = leaf_hunter(df)

print(leaf)
# Out:
# {'best_gini': 0.62, 'best_threshold': 0.4, 'best_att': 'Ba', 'node_gini': 0.736, 'class_count': array([49, 53, 12,  9,  6, 20])}

# %%
plt.scatter([i for i in range(149)], df[leaf["best_att"]], c=y, cmap=col)
plt.hlines(leaf["best_threshold"], 0, 149)
plt.title(f"{leaf['best_att']}");
#plt.savefig('../Vis/split 1');

# %%
clf = DecisionTreeClassifier(max_depth=16)
model = clf.fit(X, y)

# %%
sum(model.predict(X)-y)
# Out:
# 0

# %%
fig = plt.figure(figsize=(50,30))
_ = tree.plot_tree(model, filled= True)
print([(i, attributes[i]) for i in range(len(attributes))]);
#plt.savefig('../Vis/sklearn_tree');
# Out:
# [(0, 'RI'), (1, 'Na'), (2, 'Mg'), (3, 'Al'), (4, 'Si'), (5, 'K'), (6, 'Ca'), (7, 'Ba'), (8, 'Fe')]

# %%
#plt.scatter([i for i in range(149)], df['Ba'], c=y, cmap=col)
#plt.hlines(0.4, 0, 149)
#plt.title('Ba');

# %%
a_df = df[df[leaf['best_att']] <= leaf["best_threshold"]].copy()
b_df = df[df[leaf['best_att']] > leaf["best_threshold"]].copy()
print(a_df.shape[0], b_df.shape[0])

leaf_a  = leaf_hunter(a_df)

print(leaf_a)

plt.scatter([i for i in range(a_df.shape[0])], a_df[leaf_a['best_att']], c=a_df['type'], cmap=col)
plt.hlines(leaf_a["best_threshold"], 0, a_df.shape[0])
plt.title(f'{leaf_a["best_att"]}');
#plt.savefig('../Vis/a_split');
# Out:
# 128 21
# {'best_gini': 0.605, 'best_threshold': 1.42, 'best_att': 'Al', 'node_gini': 0.679, 'class_count': array([48, 52, 12,  8,  6,  2])}

# %%
leaf_b  = leaf_hunter(b_df)

print(leaf_b)

plt.scatter([i for i in range(b_df.shape[0])], b_df[leaf_b['best_att']], c=b_df['type'], cmap=col)
plt.hlines(leaf_b["best_threshold"], 0, b_df.shape[0])
plt.title(f'{leaf_b["best_att"]}');
#plt.savefig('../Vis/b_split');
# Out:
# {'best_gini': 0.138, 'best_threshold': 70.16, 'best_att': 'Si', 'node_gini': 0.259, 'class_count': array([ 1,  1,  0,  1,  0, 18])}

# %%
y_classes = {0:'wind_float', 1:'wind_non', 2: 'wind_veh', 3:'container', 4:'tableware', 5:'headlamp'}

class Noodle:
    
    def __init__(self, df, max_depth=10, print_nodes=False, depth=0):     
        tmp = leaf_hunter(df)
        self.depth = depth
        self.node_gini = tmp['node_gini']
        self.best_gini = tmp['best_gini']
        self.best_att = tmp['best_att']
        self.best_threshold = tmp['best_threshold']
        self.class_count = tmp['class_count']
        self.no_classes = len(np.nonzero(self.class_count)[0])
        self.max_depth = max_depth
        self.classification = y_classes[int(np.where(self.class_count == np.amax(self.class_count))[0][0])] 
        
        if self.no_classes == 1 or self.max_depth < 1:
            self.has_children = False
        else:
            self.has_children = True
        
        if print_nodes:
            print(self)
        
        
        if self.has_children:
            a = df[df[self.best_att] <= self.best_threshold]
            b = df[df[self.best_att] > self.best_threshold]
            self.child_a = Noodle(a, self.max_depth-1, print_nodes, self.depth+1)
            self.child_b = Noodle(b, self.max_depth-1, print_nodes, self.depth+1)
            
            
    def __str__ (self):
        
        peanut = {attributes[i]: i for i in range(len(attributes))}
        peanut[0] = ''
        
        
        return(f'Depth: {self.depth}'
              + f'\n{"  "*self.depth}Node Gini: {self.node_gini}'
              + f'\n{"  "*self.depth}Attribute: {self.best_att} ({peanut[self.best_att]})'
              + f'\n{"  "*self.depth}Threshold: {self.best_threshold}'
              + f'\n{"  "*self.depth}Classes: {self.class_count}'
              + f'\n{"  "*self.depth}No classes: {self.no_classes}'
              + f'\n{"  "*self.depth}Node classification: {self.classification}'
              + f'\n{"  "*self.depth}Has children: {self.has_children}'
              + f'\n{"  "*self.depth}-----------------------\n')
        

        
bob = Noodle(df, print_nodes=True) # This fits the model to the data equiv to .fit()
# Out:
# Depth: 0
# Node Gini: 0.736
# Attribute: Ba (7)
# Threshold: 0.4
# Classes: [49 53 12  9  6 20]
# No classes: 6
# Node classification: wind_non
# Has children: True
# -----------------------
#
# Depth: 1
#   Node Gini: 0.679
#   Attribute: Al (3)
#   Threshold: 1.42
#   Classes: [48 52 12  8  6  2]
#   No classes: 6
#   Node classification: wind_non
#   Has children: True
#   -----------------------
#
# Depth: 2
#     Node Gini: 0.612
#     Attribute: Ca (6)
#     Threshold: 10.48
#     Classes: [43 23 10  1  2  1]
#     No classes: 6
#     Node classification: wind_float
#     Has children: True
#     -----------------------
#
# Depth: 3
#       Node Gini: 0.568
#       Attribute: Mg (2)
#       Threshold: 3.865
#       Classes: [43 17 10  0  1  1]
#       No classes: 5
#       Node classification: wind_float
#       Has children: True
#       -----------------------
#
# Depth: 4
#         Node Gini: 0.532
#         Attribute: Fe (8)
#         Threshold: 0.115
#         Classes: [43 13  9  0  1  1]
#         No classes: 5
#         Node classification: wind_float
#         Has children: True
#         -----------------------
#
# Depth: 5
#           Node Gini: 0.439
#           Attribute: RI (0)
#           Threshold: 1.5175
#           Classes: [35  4  7  0  1  1]
#           No classes: 5
#           Node classification: wind_float
#           Has children: True
#           -----------------------
#
# Depth: 6
#             Node Gini: 0.64
#             Attribute: Al (3)
#             Threshold: 1.25
#             Classes: [3 1 5 0 1 0]
#             No classes: 4
#             Node classification: wind_veh
#             Has children: True
#             -----------------------
#
# Depth: 7
#               Node Gini: 0.375
#               Attribute: RI (0)
#               Threshold: 1.514
#               Classes: [3 0 0 0 1 0]
#               No classes: 2
#               Node classification: wind_float
#               Has children: True
#               -----------------------
#
# Depth: 8
#                 Node Gini: 0
#                 Attribute: 0 ()
#                 Threshold: 0
#                 Classes: [0 0 0 0 1 0]
#                 No classes: 1
#                 Node classification: tableware
#                 Has children: False
#                 -----------------------
#
# Depth: 8
#                 Node Gini: 0.0
#                 Attribute: Na (1)
#                 Threshold: 13.055
#                 Classes: [3 0 0 0 0 0]
#                 No classes: 1
#                 Node classification: wind_float
#                 Has children: False
#                 -----------------------
#
# Depth: 7
#               Node Gini: 0.278
#               Attribute: Mg (2)
#               Threshold: 3.595
#               Classes: [0 1 5 0 0 0]
#               No classes: 2
#               Node classification: wind_veh
#               Has children: True
#               -----------------------
#
# Depth: 8
#                 Node Gini: 0.0
#                 Attribute: RI (0)
#                 Threshold: 1.5165
#                 Classes: [0 0 5 0 0 0]
#                 No classes: 1
#                 Node classification: wind_veh
#                 Has children: False
#                 -----------------------
#
# Depth: 8
#                 Node Gini: 0
#                 Attribute: 0 ()
#                 Threshold: 0
#                 Classes: [0 1 0 0 0 0]
#                 No classes: 1
#                 Node classification: wind_non
#                 Has children: False
#                 -----------------------
#
# Depth: 6
#             Node Gini: 0.281
#             Attribute: Mg (2)
#             Threshold: 3.63
#             Classes: [32  3  2  0  0  1]
#             No classes: 4
#             Node classification: wind_float
#             Has children: True
#             -----------------------
#
# Depth: 7
#               Node Gini: 0.087
#               Attribute: RI (0)
#               Threshold: 1.522
#               Classes: [21  0  0  0  0  1]
#               No classes: 2
#               Node classification: wind_float
#               Has children: True
#               -----------------------
#
# Depth: 8
#                 Node Gini: 0.0
#                 Attribute: RI (0)
#                 Threshold: 1.5185
#                 Classes: [20  0  0  0  0  0]
#                 No classes: 1
#                 Node classification: wind_float
#                 Has children: False
#                 -----------------------
#
# Depth: 8
#                 Node Gini: 0.5
#                 Attribute: Na (1)
#                 Threshold: 13.375
#                 Classes: [1 0 0 0 0 1]
#                 No classes: 2
#                 Node classification: wind_float
#                 Has children: True
#                 -----------------------
#
# Depth: 9
#                   Node Gini: 0
#                   Attribute: 0 ()
#                   Threshold: 0
#                   Classes: [1 0 0 0 0 0]
#                   No classes: 1
#                   Node classification: wind_float
#                   Has children: False
#                   -----------------------
#
# Depth: 9
#                   Node Gini: 0
#                   Attribute: 0 ()
#                   Threshold: 0
#                   Classes: [0 0 0 0 0 1]
#                   No classes: 1
#                   Node classification: headlamp
#                   Has children: False
#                   -----------------------
#
# Depth: 7
#               Node Gini: 0.477
#               Attribute: Mg (2)
#               Threshold: 3.665
#               Classes: [11  3  2  0  0  0]
#               No classes: 3
#               Node classification: wind_float
#               Has children: True
#               -----------------------
#
# Depth: 8
#                 Node Gini: 0.0
#                 Attribute: Na (1)
#                 Threshold: 13.645
#                 Classes: [0 0 2 0 0 0]
#                 No classes: 1
#                 Node classification: wind_veh
#                 Has children: False
#                 -----------------------
#
# Depth: 8
#                 Node Gini: 0.337
#                 Attribute: Ca (6)
#                 Threshold: 8.61
#                 Classes: [11  3  0  0  0  0]
#                 No classes: 2
#                 Node classification: wind_float
#                 Has children: True
#                 -----------------------
#
# Depth: 9
#                   Node Gini: 0.48
#                   Attribute: Mg (2)
#                   Threshold: 3.75
#                   Classes: [2 3 0 0 0 0]
#                   No classes: 2
#                   Node classification: wind_non
#                   Has children: True
#                   -----------------------
#
# Depth: 10
#                     Node Gini: 0.444
#                     Attribute: RI (0)
#                     Threshold: 1.52
#                     Classes: [2 1 0 0 0 0]
#                     No classes: 2
#                     Node classification: wind_float
#                     Has children: False
#                     -----------------------
#
# Depth: 10
#                     Node Gini: 0.0
#                     Attribute: Na (1)
#                     Threshold: 13.29
#                     Classes: [0 2 0 0 0 0]
#                     No classes: 1
#                     Node classification: wind_non
#                     Has children: False
#                     -----------------------
#
# Depth: 9
#                   Node Gini: 0.0
#                   Attribute: RI (0)
#                   Threshold: 1.519
#                   Classes: [9 0 0 0 0 0]
#                   No classes: 1
#                   Node classification: wind_float
#                   Has children: False
#                   -----------------------
#
# Depth: 5
#           Node Gini: 0.587
#           Attribute: Al (3)
#           Threshold: 1.26
#           Classes: [8 9 2 0 0 0]
#           No classes: 3
#           Node classification: wind_non
#           Has children: True
#           -----------------------
#
# Depth: 6
#             Node Gini: 0.551
#             Attribute: K (5)
#             Threshold: 0.29
#             Classes: [4 9 2 0 0 0]
#             No classes: 3
#             Node classification: wind_non
#             Has children: True
#             -----------------------
#
# Depth: 7
#               Node Gini: 0.5
#               Attribute: Ca (6)
#               Threshold: 9.495
#               Classes: [2 0 2 0 0 0]
#               No classes: 2
#               Node classification: wind_float
#               Has children: True
#               -----------------------
#
# Depth: 8
#                 Node Gini: 0.0
#                 Attribute: RI (0)
#                 Threshold: 1.5205
#                 Classes: [0 0 2 0 0 0]
#                 No classes: 1
#                 Node classification: wind_veh
#                 Has children: False
#                 -----------------------
#
# Depth: 8
#                 Node Gini: 0.0
#                 Attribute: RI (0)
#                 Threshold: 1.5225
#                 Classes: [2 0 0 0 0 0]
#                 No classes: 1
#                 Node classification: wind_float
#                 Has children: False
#                 -----------------------
# Depth: 7
#               Node Gini: 0.298
#               Attribute: Fe (8)
#               Threshold: 0.27
#               Classes: [2 9 0 0 0 0]
#               No classes: 2
#               Node classification: wind_non
#               Has children: True
#               -----------------------
#
# Depth: 8
#                 Node Gini: 0.0
#                 Attribute: RI (0)
#                 Threshold: 1.5165
#                 Classes: [0 8 0 0 0 0]
#                 No classes: 1
#                 Node classification: wind_non
#                 Has children: False
#                 -----------------------
#
# Depth: 8
#                 Node Gini: 0.444
#                 Attribute: Mg (2)
#                 Threshold: 3.57
#                 Classes: [2 1 0 0 0 0]
#                 No classes: 2
#                 Node classification: wind_float
#                 Has children: True
#                 -----------------------
#
# Depth: 9
#                   Node Gini: 0.0
#                   Attribute: RI (0)
#                   Threshold: 1.515
#                   Classes: [2 0 0 0 0 0]
#                   No classes: 1
#                   Node classification: wind_float
#                   Has children: False
#                   -----------------------
#
# Depth: 9
#                   Node Gini: 0
#                   Attribute: 0 ()
#                   Threshold: 0
#                   Classes: [0 1 0 0 0 0]
#                   No classes: 1
#                   Node classification: wind_non
#                   Has children: False
#                   -----------------------
#
# Depth: 6
#             Node Gini: 0.0
#             Attribute: RI (0)
#             Threshold: 1.5165
#             Classes: [4 0 0 0 0 0]
#             No classes: 1
#             Node classification: wind_float
#             Has children: False
#             -----------------------
#
# Depth: 4
#         Node Gini: 0.32
#         Attribute: RI (0)
#         Threshold: 1.5195
#         Classes: [0 4 1 0 0 0]
#         No classes: 2
#         Node classification: wind_non
#         Has children: True
#         -----------------------
#
# Depth: 5
#           Node Gini: 0.0
#           Attribute: Na (1)
#           Threshold: 13.325
#           Classes: [0 4 0 0 0 0]
#           No classes: 1
#           Node classification: wind_non
#           Has children: False
#           -----------------------
#
# Depth: 5
#           Node Gini: 0
#           Attribute: 0 ()
#           Threshold: 0
#           Classes: [0 0 1 0 0 0]
#           No classes: 1
#           Node classification: wind_veh
#           Has children: False
#           -----------------------
#
# Depth: 3
#       Node Gini: 0.406
#       Attribute: RI (0)
#       Threshold: 1.521
#       Classes: [0 6 0 1 1 0]
#       No classes: 3
#       Node classification: wind_non
#       Has children: True
#       -----------------------
#
# Depth: 4
#         Node Gini: 0.5
#         Attribute: Na (1)
#         Threshold: 13.97
#         Classes: [0 0 0 1 1 0]
#         No classes: 2
#         Node classification: container
#         Has children: True
#         -----------------------
#
# Depth: 5
#           Node Gini: 0
#           Attribute: 0 ()
#           Threshold: 0
#           Classes: [0 0 0 1 0 0]
#           No classes: 1
#           Node classification: container
#           Has children: False
#           -----------------------
#
# Depth: 5
#           Node Gini: 0
#           Attribute: 0 ()
#           Threshold: 0
#           Classes: [0 0 0 0 1 0]
#           No classes: 1
#           Node classification: tableware
#           Has children: False
#           -----------------------
#
# Depth: 4
#         Node Gini: 0.0
#         Attribute: RI (0)
#         Threshold: 1.523
#         Classes: [0 6 0 0 0 0]
#         No classes: 1
#         Node classification: wind_non
#         Has children: False
#         -----------------------
#
# Depth: 2
#     Node Gini: 0.594
#     Attribute: Mg (2)
#     Threshold: 1.985
#     Classes: [ 5 29  2  7  4  1]
#     No classes: 6
#     Node classification: wind_non
#     Has children: True
#     -----------------------
#
# Depth: 3
#       Node Gini: 0.42
#       Attribute: Na (1)
#       Threshold: 13.795
#       Classes: [0 0 0 7 3 0]
#       No classes: 2
#       Node classification: container
#       Has children: True
#       -----------------------
#
# Depth: 4
#         Node Gini: 0.0
#         Attribute: RI (0)
#         Threshold: 1.515
#         Classes: [0 0 0 7 0 0]
#         No classes: 1
#         Node classification: container
#         Has children: False
#         -----------------------
#
# Depth: 4
#         Node Gini: 0.0
#         Attribute: RI (0)
#         Threshold: 1.516
#         Classes: [0 0 0 0 3 0]
#         No classes: 1
#         Node classification: tableware
#         Has children: False
#         -----------------------
#
# Depth: 3
#       Node Gini: 0.396
#       Attribute: RI (0)
#       Threshold: 1.5215
#       Classes: [ 5 29  2  0  1  1]
#       No classes: 5
#       Node classification: wind_non
#       Has children: True
#       -----------------------
#
# Depth: 4
#         Node Gini: 0.364
#         Attribute: K (5)
#         Threshold: 0.035
#         Classes: [ 5 29  2  0  1  0]
#         No classes: 4
#         Node classification: wind_non
#         Has children: True
#         -----------------------
#
# Depth: 5
#           Node Gini: 0
#           Attribute: 0 ()
#           Threshold: 0
#           Classes: [0 0 0 0 1 0]
#           No classes: 1
#           Node classification: tableware
#           Has children: False
#           -----------------------
#
# Depth: 5
#           Node Gini: 0.329
#           Attribute: Na (1)
#           Threshold: 12.835
#           Classes: [ 5 29  2  0  0  0]
#           No classes: 3
#           Node classification: wind_non
#           Has children: True
#           -----------------------
#
# Depth: 6
#             Node Gini: 0.5
#             Attribute: Fe (8)
#             Threshold: 0.095
#             Classes: [3 3 0 0 0 0]
#             No classes: 2
#             Node classification: wind_float
#             Has children: True
#             -----------------------
#
# Depth: 7
#               Node Gini: 0.0
#               Attribute: RI (0)
#               Threshold: 1.5165
#               Classes: [0 3 0 0 0 0]
#               No classes: 1
#               Node classification: wind_non
#               Has children: False
#               -----------------------
#
# Depth: 7
#               Node Gini: 0.0
#               Attribute: RI (0)
#               Threshold: 1.517
#               Classes: [3 0 0 0 0 0]
#               No classes: 1
#               Node classification: wind_float
#               Has children: False
#               -----------------------
#
# Depth: 6
#             Node Gini: 0.24
#             Attribute: K (5)
#             Threshold: 0.605
#             Classes: [ 2 26  2  0  0  0]
#             No classes: 3
#             Node classification: wind_non
#             Has children: True
#             -----------------------
#
# Depth: 7
#               Node Gini: 0.449
#               Attribute: Al (3)
#               Threshold: 1.75
#               Classes: [ 2 10  2  0  0  0]
#               No classes: 3
#               Node classification: wind_non
#               Has children: True
#               -----------------------
#
# Depth: 8
#                 Node Gini: 0.379
#                 Attribute: Fe (8)
#                 Threshold: 0.105
#                 Classes: [ 2 10  1  0  0  0]
#                 No classes: 3
#                 Node classification: wind_non
#                 Has children: True
#                 -----------------------
#
# Depth: 9
#                   Node Gini: 0.571
#                   Attribute: Al (3)
#                   Threshold: 1.51
#                   Classes: [2 4 1 0 0 0]
#                   No classes: 3
#                   Node classification: wind_non
#                   Has children: True
#                   -----------------------
#
# Depth: 10
#                     Node Gini: 0.0
#                     Attribute: RI (0)
#                     Threshold: 1.5165
#                     Classes: [0 4 0 0 0 0]
#                     No classes: 1
#                     Node classification: wind_non
#                     Has children: False
#                     -----------------------
#
# Depth: 10
#                     Node Gini: 0.444
#                     Attribute: RI (0)
#                     Threshold: 1.5175
#                     Classes: [2 0 1 0 0 0]
#                     No classes: 2
#                     Node classification: wind_float
#                     Has children: False
#                     -----------------------
#
# Depth: 9
#                   Node Gini: 0.0
#                   Attribute: RI (0)
#                   Threshold: 1.517
#                   Classes: [0 6 0 0 0 0]
#                   No classes: 1
#                   Node classification: wind_non
#                   Has children: False
#                   -----------------------
# Depth: 8
#                 Node Gini: 0
#                 Attribute: 0 ()
#                 Threshold: 0
#                 Classes: [0 0 1 0 0 0]
#                 No classes: 1
#                 Node classification: wind_veh
#                 Has children: False
#                 -----------------------
#
# Depth: 7
#               Node Gini: 0.0
#               Attribute: RI (0)
#               Threshold: 1.515
#               Classes: [ 0 16  0  0  0  0]
#               No classes: 1
#               Node classification: wind_non
#               Has children: False
#               -----------------------
#
# Depth: 4
#         Node Gini: 0
#         Attribute: 0 ()
#         Threshold: 0
#         Classes: [0 0 0 0 0 1]
#         No classes: 1
#         Node classification: headlamp
#         Has children: False
#         -----------------------
#
# Depth: 1
#   Node Gini: 0.259
#   Attribute: Si (4)
#   Threshold: 70.16
#   Classes: [ 1  1  0  1  0 18]
#   No classes: 4
#   Node classification: headlamp
#   Has children: True
#   -----------------------
#
# Depth: 2
#     Node Gini: 0.5
#     Attribute: RI (0)
#     Threshold: 1.523
#     Classes: [0 1 0 1 0 0]
#     No classes: 2
#     Node classification: wind_non
#     Has children: True
#     -----------------------
#
# Depth: 3
#       Node Gini: 0
#       Attribute: 0 ()
#       Threshold: 0
#       Classes: [0 0 0 1 0 0]
#       No classes: 1
#       Node classification: container
#       Has children: False
#       -----------------------
#
# Depth: 3
#       Node Gini: 0
#       Attribute: 0 ()
#       Threshold: 0
#       Classes: [0 1 0 0 0 0]
#       No classes: 1
#       Node classification: wind_non
#       Has children: False
#       -----------------------
#
# Depth: 2
#     Node Gini: 0.1
#     Attribute: Mg (2)
#     Threshold: 3.42
#     Classes: [ 1  0  0  0  0 18]
#     No classes: 2
#     Node classification: headlamp
#     Has children: True
#     -----------------------
#
# Depth: 3
#       Node Gini: 0.0
#       Attribute: RI (0)
#       Threshold: 1.513
#       Classes: [ 0  0  0  0  0 18]
#       No classes: 1
#       Node classification: headlamp
#       Has children: False
#       -----------------------
#
# Depth: 3
#       Node Gini: 0
#       Attribute: 0 ()
#       Threshold: 0
#       Classes: [1 0 0 0 0 0]
#       No classes: 1
#       Node classification: wind_float
#       Has children: False
#       -----------------------

# %%
print(bob.child_a)


print(bob.child_a.child_a)
# Out:
# Depth: 1
#   Node Gini: 0.679
#   Attribute: Al (3)
#   Threshold: 1.42
#   Classes: [48 52 12  8  6  2]
#   No classes: 6
#   Node classification: wind_non
#   Has children: True
#   -----------------------
#
# Depth: 2
#     Node Gini: 0.612
#     Attribute: Ca (6)
#     Threshold: 10.48
#     Classes: [43 23 10  1  2  1]
#     No classes: 6
#     Node classification: wind_float
#     Has children: True
#     -----------------------

# %%
banana = 0 # keeps track of correct classifications
df_trained = df.copy()
df_trained['classification'] = ''

for i in range(149):
    test = df.iloc[i]
    searching = True
    sam = bob # makes sam a copy of the decision tree
    while searching:
        if sam.has_children:
            if test[sam.best_att] <= sam.best_threshold:
                sam = sam.child_a
            else:
                sam = sam.child_b
        else:
            searching = False
    df_trained['classification'].iloc[i] = sam.classification
    if sam.classification == test['type_desc']:
        banana +=1
    else:
        print('wrong', i, test['type_desc'], sam.classification)
        
print(f'{round(banana/1.49, 2)}% correct') #should be 100% whilst we are overtraining the model
# Out:
# wrong 79 wind_non wind_float
# wrong 117 wind_veh wind_float
# 98.66% correct

# %%
print([(0, 'RI'),
 (1, 'Na'),
 (2, 'Mg'),
 (3, 'Al'),
 (4, 'Si'),
 (5, 'K'),
 (6, 'Ca'),
 (7, 'Ba'),
 (8, 'Fe')]
)
df_trained.iloc[[117,79]]
# Out:
# [(0, 'RI'), (1, 'Na'), (2, 'Mg'), (3, 'Al'), (4, 'Si'), (5, 'K'), (6, 'Ca'), (7, 'Ba'), (8, 'Fe')]
#         RI    Na    Mg    Al     Si     K    Ca   Ba    Fe  type type_desc  \
# 117  1.518  13.5  3.36  1.63  71.94  0.57  8.81  0.0  0.09     3  wind_veh
# 79   1.522  13.2  3.68  1.15  72.75  0.54  8.52  0.0  0.00     2  wind_non
#
#     classification
# 117     wind_float
# 79      wind_float

# %%
df_test = df[df['type'] == 3]
df_test2 = df[df['type'] == 2]
df_test3 = df[df['type'] == 1]

att = 'RI'

plt.plot(df_trained.iloc[[79]][att], c='red', marker = 'o')
plt.plot(df_trained.iloc[[117]][att], c='red', marker = 'o')
plt.plot(df_test[att], 'b.')
plt.plot(df_test2[att], 'g.')
plt.plot(df_test3[att], 'k.');
